# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# masuk ke directory penyimpanan dataset anda
# %cd /content/drive/MyDrive/kaggle
# Out:
# /content/drive/MyDrive/kaggle

# %%
# !ls
# Out:
# cell-images-for-detecting-malaria.zip  x_test.npy   y_train.npy
# kaggle.json			       x_train.npy  y_val.npy
# Malaria				       x_val.npy
# new-plant-diseases-dataset.zip	       y_test.npy

# %%
import numpy as np

x_train = np.load("x_train.npy")
x_val = np.load("x_val.npy")
x_test = np.load("x_test.npy")
y_train = np.load("y_train.npy")
y_val = np.load("y_val.npy")
y_test = np.load("y_test.npy")

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, Dense, Conv2D, MaxPool2D, Flatten
import tensorflow as tf

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# augmentation
aug = ImageDataGenerator(rotation_range=10, width_shift_range=0.1, 
                         height_shift_range=0.1, horizontal_flip=True, fill_mode="nearest")

# %%
#model1 
model1 = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(250, 250, 3)),
    tf.keras.layers.MaxPooling2D(2, 2), #metode maxpooling mengambil nilai maksium pergerseran pixel yang ada
    tf.keras.layers.GlobalMaxPooling2D(), #globalmaxpooling
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(1, activation='softmax')
])

print ("Model 1 metode maxpooling")
model1.summary()
# Out:
# Model 1 metode maxpooling
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 248, 248, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 124, 124, 32)     0
#  )
#
#  global_max_pooling2d (Globa  (None, 32)               0
#  lMaxPooling2D)
#
#  flatten (Flatten)           (None, 32)                0
#
#  dense (Dense)               (None, 64)                2112
#
#  dense_1 (Dense)             (None, 128)               8320
#
#  dense_2 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 11,457
# Trainable params: 11,457
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import Adam

model1.compile(optimizer=Adam(learning_rate=0.001), #lr=0.001
              loss='categorical_crossentropy', 
              metrics=['acc'])

# %%
N = model.fit(aug.flow(x_train, y_train, batch_size=32), 
              steps_per_epoch=32,
              epochs=100, 
              validation_data=(x_val, y_val)
              )

# %%
N = model1.fit(x_train, y_train, 
              batch_size=32,
              steps_per_epoch=32, 
              epochs=100, 
              validation_data=(x_val, y_val))
# Out:
# Epoch 1/100
# 32/32 [==============================] - 52s 2s/step - loss: 0.0000e+00 - acc: 0.2598 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 2/100
# 32/32 [==============================] - 50s 2s/step - loss: 0.0000e+00 - acc: 0.2725 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 3/100
# 32/32 [==============================] - 50s 2s/step - loss: 0.0000e+00 - acc: 0.2607 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 4/100
# 32/32 [==============================] - 49s 2s/step - loss: 0.0000e+00 - acc: 0.2549 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 5/100
# 32/32 [==============================] - 48s 2s/step - loss: 0.0000e+00 - acc: 0.2344 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 6/100
# 32/32 [==============================] - 48s 2s/step - loss: 0.0000e+00 - acc: 0.2559 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 7/100
# 32/32 [==============================] - 48s 2s/step - loss: 0.0000e+00 - acc: 0.2472 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 8/100
# 32/32 [==============================] - 49s 2s/step - loss: 0.0000e+00 - acc: 0.2686 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 9/100
# 32/32 [==============================] - 49s 2s/step - loss: 0.0000e+00 - acc: 0.2705 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 10/100
# 32/32 [==============================] - 49s 2s/step - loss: 0.0000e+00 - acc: 0.2393 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 11/100
# 32/32 [==============================] - 48s 2s/step - loss: 0.0000e+00 - acc: 0.2656 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 12/100
# 32/32 [==============================] - 47s 1s/step - loss: 0.0000e+00 - acc: 0.2383 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 13/100
# 32/32 [==============================] - 47s 1s/step - loss: 0.0000e+00 - acc: 0.2563 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 14/100
# 32/32 [==============================] - 47s 1s/step - loss: 0.0000e+00 - acc: 0.2627 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 15/100
# 32/32 [==============================] - 47s 1s/step - loss: 0.0000e+00 - acc: 0.2637 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 16/100
# 32/32 [==============================] - 47s 1s/step - loss: 0.0000e+00 - acc: 0.2607 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 17/100
# 32/32 [==============================] - 47s 1s/step - loss: 0.0000e+00 - acc: 0.2363 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 18/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0000e+00 - acc: 0.2520 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 19/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0000e+00 - acc: 0.2442 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 20/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0000e+00 - acc: 0.2812 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 21/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0000e+00 - acc: 0.2578 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 22/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0000e+00 - acc: 0.2529 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 23/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0000e+00 - acc: 0.2695 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 24/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0000e+00 - acc: 0.2432 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 25/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0000e+00 - acc: 0.2392 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 26/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0000e+00 - acc: 0.2461 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 27/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0000e+00 - acc: 0.2578 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 28/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0000e+00 - acc: 0.2539 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 29/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0000e+00 - acc: 0.2725 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 30/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0000e+00 - acc: 0.2510 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 31/100
# 32/32 [==============================] - 47s 1s/step - loss: 0.0000e+00 - acc: 0.2743 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 32/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0000e+00 - acc: 0.2646 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 33/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0000e+00 - acc: 0.2539 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 34/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0000e+00 - acc: 0.2354 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 35/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0000e+00 - acc: 0.2539 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 36/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0000e+00 - acc: 0.2607 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 37/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0000e+00 - acc: 0.2503 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 38/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0000e+00 - acc: 0.2598 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 39/100
# 32/32 [==============================] - 47s 1s/step - loss: 0.0000e+00 - acc: 0.2568 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 40/100
# 32/32 [==============================] - 47s 1s/step - loss: 0.0000e+00 - acc: 0.2441 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 41/100
# 32/32 [==============================] - 47s 1s/step - loss: 0.0000e+00 - acc: 0.2783 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 42/100
# 32/32 [==============================] - 47s 1s/step - loss: 0.0000e+00 - acc: 0.2451 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 43/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0000e+00 - acc: 0.2432 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 44/100
# 32/32 [==============================] - 47s 1s/step - loss: 0.0000e+00 - acc: 0.2793 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 45/100
# 32/32 [==============================] - 47s 1s/step - loss: 0.0000e+00 - acc: 0.2402 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 46/100
# 32/32 [==============================] - 47s 1s/step - loss: 0.0000e+00 - acc: 0.2725 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 47/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0000e+00 - acc: 0.2324 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 48/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0000e+00 - acc: 0.2500 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 49/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0000e+00 - acc: 0.2513 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 50/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0000e+00 - acc: 0.2607 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 51/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0000e+00 - acc: 0.2422 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 52/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0000e+00 - acc: 0.2832 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 53/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0000e+00 - acc: 0.2490 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 54/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0000e+00 - acc: 0.2598 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 55/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0000e+00 - acc: 0.2472 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 56/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0000e+00 - acc: 0.2422 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 57/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0000e+00 - acc: 0.2686 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 58/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0000e+00 - acc: 0.2520 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 59/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0000e+00 - acc: 0.2695 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 60/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0000e+00 - acc: 0.2402 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 61/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0000e+00 - acc: 0.2643 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 62/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0000e+00 - acc: 0.2705 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 63/100
# 32/32 [==============================] - 48s 2s/step - loss: 0.0000e+00 - acc: 0.2402 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 64/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0000e+00 - acc: 0.2529 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 65/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0000e+00 - acc: 0.2607 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 66/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0000e+00 - acc: 0.2471 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 67/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0000e+00 - acc: 0.2637 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 68/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0000e+00 - acc: 0.2392 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 69/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0000e+00 - acc: 0.2725 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 70/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0000e+00 - acc: 0.2461 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 71/100
# 32/32 [==============================] - 47s 1s/step - loss: 0.0000e+00 - acc: 0.2666 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 72/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0000e+00 - acc: 0.2402 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 73/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0000e+00 - acc: 0.2686 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 74/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0000e+00 - acc: 0.2553 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 75/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0000e+00 - acc: 0.2568 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 76/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0000e+00 - acc: 0.2617 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 77/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0000e+00 - acc: 0.2646 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 78/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0000e+00 - acc: 0.2305 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 79/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0000e+00 - acc: 0.2627 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 80/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0000e+00 - acc: 0.2543 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 81/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0000e+00 - acc: 0.2578 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 82/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0000e+00 - acc: 0.2520 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 83/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0000e+00 - acc: 0.2764 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 84/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0000e+00 - acc: 0.2510 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 85/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0000e+00 - acc: 0.2510 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 86/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0000e+00 - acc: 0.2402 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 87/100
# 32/32 [==============================] - 47s 1s/step - loss: 0.0000e+00 - acc: 0.2578 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 88/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0000e+00 - acc: 0.2344 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 89/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0000e+00 - acc: 0.2637 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 90/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0000e+00 - acc: 0.2686 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 91/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0000e+00 - acc: 0.2617 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 92/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0000e+00 - acc: 0.2613 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 93/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0000e+00 - acc: 0.2363 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 94/100
# 32/32 [==============================] - 47s 1s/step - loss: 0.0000e+00 - acc: 0.2646 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 95/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0000e+00 - acc: 0.2666 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 96/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0000e+00 - acc: 0.2598 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 97/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0000e+00 - acc: 0.2461 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 98/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0000e+00 - acc: 0.2472 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 99/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0000e+00 - acc: 0.2539 - val_loss: 0.0000e+00 - val_acc: 0.2556
# Epoch 100/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0000e+00 - acc: 0.2754 - val_loss: 0.0000e+00 - val_acc: 0.2556

# %%
#Plot hasil training model berupa hasil validasi akurasi dan Buat report klasifikasi beserta dengan keterangan labelnya
import matplotlib.pyplot as plt
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, 100), N.history["acc"], label="acc_model_1")
plt.plot(np.arange(0, 100), N.history["val_acc"], label="val_acc_model_1")
plt.title("Acc Result Plot")
plt.xlabel("Epoch #")
plt.ylabel("Acc")
plt.legend()
plt.show()

# %%
#Plot hasil training model berupa hasil validasi loss dan Buat report klasifikasi beserta dengan keterangan labelnya
import matplotlib.pyplot as plt
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, 100), N.history["loss"], label="loss_model_1")
plt.plot(np.arange(0, 100), N.history["val_loss"], label="val_loss_model_1")
plt.title("Loss Result Plot")
plt.xlabel("Epoch #")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
#model 1
from sklearn.metrics import classification_report

pred = model1.predict(x_train)
labels = (pred > 0.5).astype(np.int)

print(classification_report(y_train, labels))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      1612
#            1       0.26      1.00      0.41      1589
#            2       0.00      0.00      0.00      1408
#            3       0.00      0.00      0.00      1606
#
#     accuracy                           0.26      6215
#    macro avg       0.06      0.25      0.10      6215
# weighted avg       0.07      0.26      0.10      6215
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
