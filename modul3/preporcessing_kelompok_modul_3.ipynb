# %% [markdown]
# #Load Data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# masuk ke directory penyimpanan dataset anda
# %cd /content/drive/MyDrive/kaggle
# Out:
# /content/drive/MyDrive/kaggle

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = "/content/drive/MyDrive/kaggle"

# %%
# jika anda ingin menggunakan kaggle API untuk mengunduh dataset gunakan
# kode berikut untuk membantu anda membuat config kaggle.json
# pastikan anda mendaftar akun kaggle terlebih dahulu
# kemudian menuju halaman my account dan buat token API anda

api_token = {"username":"r1skyhacing","key":"ecc99266ee3559ce4ed64985b3c8594e"}
import json
import zipfile
import os
with open('/content/drive/MyDrive/kaggle/kaggle.json', 'w') as file:
    json.dump(api_token, file)
# !chmod 600 /content/drive/MyDrive/kaggle/kaggle.json

# %%
# Unduh dataset dan ekstraksi zip
# !kaggle datasets download -d vipoooool/new-plant-diseases-dataset
# Out:
# ...
# 100% 2.70G/2.70G [00:40<00:00, 23.1MB/s]
# 100% 2.70G/2.70G [00:40<00:00, 71.5MB/s]

# %%
# !ls
# Out:
# kaggle.json  new-plant-diseases-dataset.zip

# %%
import os
import zipfile

local_zip = 'new-plant-diseases-dataset.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/content') #mengeksrak file zip ke direktory yang sudah ditentukan
zip_ref.close()

# %% [markdown]
# #Spliting 80% Train, 19% Validation, & 1% Test

# %%
#membuat folder baru Splitingflowers
from os import mkdir

mkdir('/content/ApplePlantDiseases')

# %%
#membuat 3 folder baru di dalam folder Splitingflowers
from os import mkdir
mkdir('/content/ApplePlantDiseases/training')
mkdir('/content/ApplePlantDiseases/validation')
mkdir('/content/ApplePlantDiseases/test')

# %%
#membuat folder kelas baru di ketifa folder diatas
from os import mkdir
mkdir('/content/ApplePlantDiseases/training/Apple___Apple_scab')
mkdir('/content/ApplePlantDiseases/training/Apple___Black_rot')
mkdir('/content/ApplePlantDiseases/training/Apple___Cedar_apple_rust')
mkdir('/content/ApplePlantDiseases/training/Apple___healthy')

mkdir('/content/ApplePlantDiseases/validation/Apple___Apple_scab')
mkdir('/content/ApplePlantDiseases/validation/Apple___Black_rot')
mkdir('/content/ApplePlantDiseases/validation/Apple___Cedar_apple_rust')
mkdir('/content/ApplePlantDiseases/validation/Apple___healthy')

mkdir('/content/ApplePlantDiseases/test/Apple___Apple_scab')
mkdir('/content/ApplePlantDiseases/test/Apple___Black_rot')
mkdir('/content/ApplePlantDiseases/test/Apple___Cedar_apple_rust')
mkdir('/content/ApplePlantDiseases/test/Apple___healthy')

# %%
#Splitting dataset "Apple_scab" yaitu dengan membuat folder gambar untuk memisahkan gambar tersebut 80% sebagai data training, 19% sebagai data validation, dan 1% sebagai data test

import os
import shutil

Apple_scab_original = "/content/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train/Apple___Apple_scab"
Apple_scab_train = "/content/ApplePlantDiseases/training/Apple___Apple_scab"
Apple_scab_validation = "/content/ApplePlantDiseases/validation/Apple___Apple_scab"
Apple_scab_test = "/content/ApplePlantDiseases/test/Apple___Apple_scab"

filesApple_scab = os.listdir(Apple_scab_original)

# memindahkan 80% file
for file in filesApple_scab[0:int(len(filesApple_scab) * .8)]:
  new_path = shutil.move(f"{Apple_scab_original}/{file}", Apple_scab_train)

# %%
filesApple_scab2 = os.listdir(Apple_scab_original)

# memindahkan 19% file
for file in filesApple_scab2[0:int(len(filesApple_scab) * .19)]:
  new_path = shutil.move(f"{Apple_scab_original}/{file}", Apple_scab_validation)

# %%
filesApple_scab3 = os.listdir(Apple_scab_original)

# memmindahkan sisa(seluruh file)
for file in filesApple_scab3:
    new_path = shutil.move(f"{Apple_scab_original}/{file}", Apple_scab_test)

# %%
#Splitting dataset "Apple_Black_rot" yaitu dengan membuat folder gambar untuk memisahkan gambar tersebut 80% sebagai data training, 19% sebagai data validation, dan 1% sebagai data test

import os
import shutil

Apple_Black_rot_original = "/content/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train/Apple___Black_rot"
Apple_Black_rot_train = "/content/ApplePlantDiseases/training/Apple___Black_rot"
Apple_Black_rot_validation = "/content/ApplePlantDiseases/validation/Apple___Black_rot"
Apple_Black_rot_test = "/content/ApplePlantDiseases/test/Apple___Black_rot"

filesApple_Black_rot = os.listdir(Apple_Black_rot_original)

# memindahkan 80% file
for file in filesApple_Black_rot[0:int(len(filesApple_Black_rot) * .8)]:
  new_path = shutil.move(f"{Apple_Black_rot_original}/{file}", Apple_Black_rot_train)

filesApple_Black_rot2 = os.listdir(Apple_Black_rot_original)

# memindahkan 19% file
for file in filesApple_Black_rot2[0:int(len(filesApple_Black_rot) * .19)]:
  new_path = shutil.move(f"{Apple_Black_rot_original}/{file}", Apple_Black_rot_validation)

filesApple_Black_rot3 = os.listdir(Apple_Black_rot_original)

# memmindahkan sisa(seluruh file)
for file in filesApple_Black_rot3:
    new_path = shutil.move(f"{Apple_Black_rot_original}/{file}", Apple_Black_rot_test)

# %%
#Splitting dataset "Apple_Cedar_apple_rust" yaitu dengan membuat folder gambar untuk memisahkan gambar tersebut 80% sebagai data training, 19% sebagai data validation, dan 1% sebagai data test

import os
import shutil

Apple_Cedar_apple_rust_original = "/content/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train/Apple___Cedar_apple_rust"
Apple_Cedar_apple_rust_train = "/content/ApplePlantDiseases/training/Apple___Cedar_apple_rust"
Apple_Cedar_apple_rust_validation = "/content/ApplePlantDiseases/validation/Apple___Cedar_apple_rust"
Apple_Cedar_apple_rust_test = "/content/ApplePlantDiseases/test/Apple___Cedar_apple_rust"

filesApple_Cedar_apple_rust = os.listdir(Apple_Cedar_apple_rust_original)

# memindahkan 80% file
for file in filesApple_Cedar_apple_rust[0:int(len(filesApple_Cedar_apple_rust) * .8)]:
  new_path = shutil.move(f"{Apple_Cedar_apple_rust_original}/{file}", Apple_Cedar_apple_rust_train)

filesApple_Cedar_apple_rust2 = os.listdir(Apple_Cedar_apple_rust_original)

# memindahkan 19% file
for file in filesApple_Cedar_apple_rust2[0:int(len(filesApple_Cedar_apple_rust) * .19)]:
  new_path = shutil.move(f"{Apple_Cedar_apple_rust_original}/{file}", Apple_Cedar_apple_rust_validation)

filesApple_Cedar_apple_rust3 = os.listdir(Apple_Cedar_apple_rust_original)

# memmindahkan sisa(seluruh file)
for file in filesApple_Cedar_apple_rust3:
    new_path = shutil.move(f"{Apple_Cedar_apple_rust_original}/{file}", Apple_Cedar_apple_rust_test)

# %%
#Splitting dataset "Apple_healthy" yaitu dengan membuat folder gambar untuk memisahkan gambar tersebut 80% sebagai data training, 19% sebagai data validation, dan 1% sebagai data test

import os
import shutil

Apple_healthy_original = "/content/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train/Apple___healthy"
Apple_healthy_train = "/content/ApplePlantDiseases/training/Apple___healthy"
Apple_healthy_validation = "/content/ApplePlantDiseases/validation/Apple___healthy"
Apple_healthy_test = "/content/ApplePlantDiseases/test/Apple___healthy"

filesApple_healthy = os.listdir(Apple_healthy_original)

# memindahkan 80% file
for file in filesApple_healthy[0:int(len(filesApple_healthy) * .8)]:
  new_path = shutil.move(f"{Apple_healthy_original}/{file}", Apple_healthy_train)

filesApple_healthy2 = os.listdir(Apple_healthy_original)

# memindahkan 19% file
for file in filesApple_healthy2[0:int(len(filesApple_healthy) * .19)]:
  new_path = shutil.move(f"{Apple_healthy_original}/{file}", Apple_healthy_validation)

filesApple_healthy3 = os.listdir(Apple_healthy_original)

# memmindahkan sisa(seluruh file)
for file in filesApple_healthy3:
    new_path = shutil.move(f"{Apple_healthy_original}/{file}", Apple_healthy_test)

# %%
file_train_Apple_scab = os.listdir(Apple_scab_train)
file_validation_Apple_scab = os.listdir(Apple_scab_validation)
file_test_Apple_scab = os.listdir(Apple_scab_test)

file_train_Apple_Black_rot = os.listdir(Apple_Black_rot_train)
file_validation_Apple_Black_rot = os.listdir(Apple_Black_rot_validation)
file_test_Apple_Black_rot = os.listdir(Apple_Black_rot_test)

file_train_Apple_Cedar_apple_rust = os.listdir(Apple_Cedar_apple_rust_train)
file_validation_Apple_Cedar_apple_rust = os.listdir(Apple_Cedar_apple_rust_validation)
file_test_Apple_Cedar_apple_rust = os.listdir(Apple_Cedar_apple_rust_test)

file_train_Apple_healthy = os.listdir(Apple_healthy_train)
file_validation_Apple_healthy = os.listdir(Apple_healthy_validation)
file_test_Apple_healthy = os.listdir(Apple_healthy_test)

print(file_train_Apple_scab[0:int(len(file_train_Apple_scab) * .001)])
print("data Apple scab train : " + str(len(file_train_Apple_scab)))
print("data Apple scab validation : " + str(len(file_validation_Apple_scab)))
print("data Apple scab test : " + str(len(file_test_Apple_scab)))

print("data Apple Black rot train : " + str(len(file_train_Apple_Black_rot)))
print("data Apple Black rot validation : " + str(len(file_validation_Apple_Black_rot)))
print("data Apple Black rot test : " + str(len(file_test_Apple_Black_rot)))

print("data Apple Cedar apple rust train : " + str(len(file_train_Apple_Cedar_apple_rust)))
print("data Apple Cedar apple rust validation : " + str(len(file_validation_Apple_Cedar_apple_rust)))
print("data Apple Cedar apple rust test : " + str(len(file_test_Apple_Cedar_apple_rust)))

print("data Apple healthy train : " + str(len(file_train_Apple_healthy)))
print("data Apple healthy validation : " + str(len(file_validation_Apple_healthy)))
print("data Apple healthy test : " + str(len(file_test_Apple_healthy)))
# Out:
# ['461eeeb9-5bf1-4c0a-a7dd-6967917b4537___FREC_Scab 3098_90deg.JPG']
# data Apple scab train : 1612
# data Apple scab validation : 383
# data Apple scab test : 21
# data Apple Black rot train : 1589
# data Apple Black rot validation : 377
# data Apple Black rot test : 21
# data Apple Cedar apple rust train : 1408
# data Apple Cedar apple rust validation : 334
# data Apple Cedar apple rust test : 18
# data Apple healthy train : 1606
# data Apple healthy validation : 381
# data Apple healthy test : 21

# %%
# Tampilkan 4 image per label beserta judul label dengan ukuran 2 baris x 4 kolom
import matplotlib.pyplot as plt
import matplotlib.image as mping

Apple_scab_dir=os.path.join('/content/ApplePlantDiseases/training/Apple___Apple_scab')
Apple_Black_rot_dir=os.path.join('/content/ApplePlantDiseases/training/Apple___Black_rot')
Apple_Cedar_apple_rust_dir=os.path.join('/content/ApplePlantDiseases/training/Apple___Cedar_apple_rust')
Apple_healthy_dir=os.path.join('/content/ApplePlantDiseases/training/Apple___healthy')

Apple_scab_image = os.listdir(Apple_scab_dir)
Apple_Black_rot_image = os.listdir(Apple_Black_rot_dir)
Apple_Cedar_apple_rust_image = os.listdir(Apple_Cedar_apple_rust_dir)
Apple_healthy_image = os.listdir(Apple_healthy_dir)


fname1 = [os.path.join(Apple_scab_dir,fname)
        for fname in Apple_scab_image[:5]]

fname2 = [os.path.join(Apple_Black_rot_dir,fname)
        for fname in Apple_Black_rot_image[:5]]

fname3 = [os.path.join(Apple_Cedar_apple_rust_dir,fname)
        for fname in Apple_Cedar_apple_rust_image[:5]]

fname4 = [os.path.join(Apple_healthy_dir,fname)
        for fname in Apple_healthy_image[:5]]



ncolu = 5
nrow = 5
fig = plt.gcf()
fig.set_size_inches(ncolu*5,nrow*5)
for i,fname in enumerate(fname1):
    sp = plt.subplot(5,5,i+1)
    sp.axis('off')
    img = mping.imread(fname)
    plt.title('Apple scab')
    plt.imshow(img)
plt.show()

ncolu = 5
nrow = 5
fig = plt.gcf()
fig.set_size_inches(ncolu*5,nrow*5)
for i,fname in enumerate(fname2):
    sp = plt.subplot(5,5,i+1)
    sp.axis('off')
    img = mping.imread(fname)
    plt.title('Apple Black rot')
    plt.imshow(img)
plt.show()

ncolu = 5
nrow = 5
fig = plt.gcf()
fig.set_size_inches(ncolu*5,nrow*5)
for i,fname in enumerate(fname3):
    sp = plt.subplot(5,5,i+1)
    sp.axis('off')
    img = mping.imread(fname)
    plt.title('Apple Cedar apple rust')
    plt.imshow(img)
plt.show()

ncolu = 5
nrow = 5
fig = plt.gcf()
fig.set_size_inches(ncolu*5,nrow*5)
for i,fname in enumerate(fname4):
    sp = plt.subplot(5,5,i+1)
    sp.axis('off')
    img = mping.imread(fname)
    plt.title('Apple healthy')
    plt.imshow(img)
plt.show()

# %% [markdown]
# #Preprocessing

# %%
#Gather data training dengan ukuran gambar 250 x 250

import os
import cv2
import numpy as np

# Gather data train inisialisasi kosongan
train_data = []
train_label = []

train_dir=os.path.join('/content/ApplePlantDiseases/training')
for r, d, f in os.walk(train_dir):
    for file in f:
        if ".JPG" in file:
            imagePath = os.path.join(r, file)
            image = cv2.imread(imagePath)
            image = cv2.resize(image, (250,250))
            train_data.append(image)
            label = imagePath.split(os.path.sep)[-2]
            train_label.append(label)

train_data = np.array(train_data)
train_label = np.array(train_label)

# %%
#Gather data validation dengan ukuran gambar 250 x 250

val_data = []
val_label = []

vali_dir=os.path.join('/content/ApplePlantDiseases/validation')
for r, d, f in os.walk(vali_dir):
    for file in f:
        if ".JPG" in file:
            imagePath = os.path.join(r, file)
            image = cv2.imread(imagePath)
            image = cv2.resize(image, (250,250))
            val_data.append(image)
            label = imagePath.split(os.path.sep)[-2]
            val_label.append(label)

val_data = np.array(val_data)
val_label = np.array(val_label)

# %%
#Gather data test dengan ukuran gambar 250 x 250

test_data = []
test_label = []

test_dir=os.path.join('/content/ApplePlantDiseases/test')
for r, d, f in os.walk(test_dir):
    for file in f:
        if ".JPG" in file:
            imagePath = os.path.join(r, file)
            image = cv2.imread(imagePath)
            image = cv2.resize(image, (250,250))
            test_data.append(image)
            label = imagePath.split(os.path.sep)[-2]
            test_label.append(label)

test_data = np.array(test_data)
test_label = np.array(test_label)

# %%
#Tampilkan shape dari data train, data validation dan data test

print("Train Data = ", train_data.shape)
print("Train Label = ", train_label.shape)
print("Validation Data = ", val_data.shape)
print("Validation Label = ", val_label.shape)
print("Test Data = ", test_data.shape)
print("Test Label = ", test_label.shape)
# Out:
# Train Data =  (6215, 250, 250, 3)
# Train Label =  (6215,)
# Validation Data =  (1475, 250, 250, 3)
# Validation Label =  (1475,)
# Test Data =  (81, 250, 250, 3)
# Test Label =  (81,)

# %%
# Normalisasi dataset

print("Data sebelum di-normalisasi ", train_data[0][0][0])
x_train = train_data.astype('float32') / 255.0
x_val = val_data.astype('float32') / 255.0
x_test = test_data.astype('float32') / 255.0
print("Data setelah di-normalisasi ", x_train[0][0][0])
# Out:
# Data sebelum di-normalisasi  [91 91 85]
# Data setelah di-normalisasi  [0.35686275 0.35686275 0.33333334]

# %%
# membuat dan menampilkan hasil dari label encoder

from sklearn.preprocessing import LabelEncoder
print("Label sebelum di-encoder ", train_label[0:10])

lb = LabelEncoder()
y_train = lb.fit_transform(train_label)
y_val = lb.fit_transform(val_label)
y_test = lb.fit_transform(test_label)

print("Label setelah di-encoder ", y_train[0:10])
# Out:
# Label sebelum di-encoder  ['Apple___Cedar_apple_rust' 'Apple___Cedar_apple_rust'
#  'Apple___Cedar_apple_rust' 'Apple___Cedar_apple_rust'
#  'Apple___Cedar_apple_rust' 'Apple___Cedar_apple_rust'
#  'Apple___Cedar_apple_rust' 'Apple___Cedar_apple_rust'
#  'Apple___Cedar_apple_rust' 'Apple___Cedar_apple_rust']
# Label setelah di-encoder  [2 2 2 2 2 2 2 2 2 2]

# %%
np.save("x_train", x_train)
np.save("x_val", x_val)
np.save("x_test", x_test)
np.save('y_train', y_train)
np.save('y_val', y_val)
np.save('y_test', y_test)
